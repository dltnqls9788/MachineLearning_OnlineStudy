# %% [markdown]
# ### 추천 시스템의 중요성
#
# ![IMG_0470.jpg](attachment:IMG_0470.jpg)

# %% [markdown]
# ### 추천엔진의 필요성
#
# ![IMG_0471.jpg](attachment:IMG_0471.jpg)

# %% [markdown]
# ### 추천 시스템 방식
# ![IMG_0472.jpg](attachment:IMG_0472.jpg)

# %% [markdown]
# # 콘텐츠 기반 필터링
#
# ![IMG_0473.jpg](attachment:IMG_0473.jpg)

# %% [markdown]
# ### 콘텐츠 기반 필터링 기법
# ![IMG_0474.jpg](attachment:IMG_0474.jpg)

# %% [markdown]
# ### 콘텐츠 기반 필터링 실습 - TMDB 5000(kaggle)
#
# #### 콘텐츠 기반 필터링 구현 프로세스
# 1. 콘텐츠에 대한 여러 텍스트 정보들을 피처 벡터화
# 2. 코사인 유사도로 콘텐츠별 유사도 계산
# 3. 콘텐츠 별로 가중 평점을 계산
# 4. 유사도가 높은 콘텐츠 중에 평점이 좋은 콘텐츠 순으로 추천
